# %%
import pandas as pd
import numpy as np
from pandas import Series
from datetime import datetime

year = 2015
month  = 1
day = 22
hour = 15
minutes = 12

datetime(year, month,day, hour, minutes)
# Out:
# datetime.datetime(2015, 1, 22, 15, 12)

# %%
myser = pd.Series(['1990-01-11','2000-08-15',None], index = ['a','b','c'])
myser
# Out:
# a    1990-01-11
# b    2000-08-15
# c          None
# dtype: object

# %%
timeser = pd.to_datetime(myser)
timeser
# Out:
# a   1990-01-11
# b   2000-08-15
# c          NaT
# dtype: datetime64[ns]

# %%
timeser[1].year
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_1281/3785137969.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   timeser[1].year
# 2000

# %%
euro_date = '15--May--2015'
pd.to_datetime(euro_date, format = '%d--%b--%Y')
# Out:
# Timestamp('2015-05-15 00:00:00')

# %%
date = '15th of august 2000'
pd.to_datetime(date)
# Out:
# Timestamp('2000-08-15 00:00:00')

# %%
file = pd.read_csv('SPY2000_2021.csv', parse_dates = [0])
file = file.set_index('Date')

# %%
file.resample(rule = 'M').mean()
# Out:
# /var/folders/1q/jjlnxt5j4dg2mnmw35tf858m0000gn/T/ipykernel_1281/956391116.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   file.resample(rule = 'M').mean()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-31  143.335156  144.464063  141.222656  142.762500   95.713264
# 2000-02-29  139.520312  140.521875  137.836719  139.070312   93.237902
# 2000-03-31  143.987772  146.023777  142.592391  144.610734   97.074775
# 2000-04-30  146.404605  148.180921  144.089638  146.337171   98.359214
# 2000-05-31  142.377841  143.598011  140.694602  142.016335   95.455006
# ...                ...         ...         ...         ...         ...
# 2020-08-31  338.100000  339.582379  336.881426  338.748095  333.776649
# 2020-09-30  337.003809  339.645236  333.019998  336.035242  331.660350
# 2020-10-31  341.394999  343.884090  338.829093  340.979094  337.319798
# ...

# %%
fb_stock = pd.read_csv('FB.csv', parse_dates = [0])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,3), dpi = 400)
fb_stock[['Adj Close']].plot(kind = 'line', c= 'purple')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
fb_stock = pd.read_csv('FB.csv')
tgt_stock = pd.read_csv('TGT.csv')
fb_stock
tgt_stock

fig, axe = plt.subplots(dpi = 300)
tgt_stock['Open'].plot(ax = axe,label = 'TGT')
fb_stock[['Open','Close']].plot(ax = axe ,label= 'FB')
plt.legend(loc = (0.5,0.5))
plt.xlabel('PLT Label')
plt.ylabel ('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
fb_stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2016-09-06  126.669998  129.940002  126.470001  129.729996  129.729996
# 1     2016-09-07  130.039993  131.979996  129.949997  131.050003  131.050003
# 2     2016-09-08  130.919998  131.080002  129.809998  130.270004  130.270004
# 3     2016-09-09  129.710007  129.949997  127.099998  127.099998  127.099998
# 4     2016-09-12  125.959999  128.759995  125.750000  128.690002  128.690002
# ...          ...         ...         ...         ...         ...         ...
# 1253  2021-08-27  365.100006  373.739990  364.079987  372.630005  372.630005
# 1254  2021-08-30  372.559998  381.489990  370.519989  380.660004  380.660004
# 1255  2021-08-31  379.950012  382.760010  378.799988  379.380005  379.380005
# 1256  2021-09-01  379.589996  384.329987  378.809998  382.049988  382.049988
# 1257  2021-09-02  381.500000  381.750000  374.059998  375.279999  375.279999
#
#         Volume
# 0     26278400
# ...

# %%
cost = pd.read_csv('COST.csv', parse_dates = [0], index_col = 'Date')
cost['Adj Close'].plot(xlim = ['2020-01-01','2021-02-01'] ,ylim = [150,400]);

# %%
from matplotlib import dates

# %%
from matplotlib import dates
import matplotlib.pyplot as plt

plt.figure(dpi = 300)
ax = cost['Close']['2018-01-01':'2018-03-01'].plot()

ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y-%B'))

# %%
walm = pd.read_csv('WMT.csv', index_col = 'Date', parse_dates = [0])
plt.figure(figsize = (10,3), dpi = 300)
walm['Adj Close'].plot(label = 'ADJ Close of Walmart')
walm['Adj Close'].rolling(window=50).mean().plot(label = '50 MA')
plt.legend()

# %%
walm['Adj Close'].rolling(window=2).mean()
# Out:
# Date
# 2016-09-06           NaN
# 2016-09-07     65.334702
# 2016-09-08     64.807743
# 2016-09-09     64.015053
# 2016-09-12     64.064590
#                  ...
# 2021-08-27    146.935005
# 2021-08-30    147.110001
# 2021-08-31    147.900002
# 2021-09-01    147.940002
# 2021-09-02    148.169999
# Name: Adj Close, Length: 1258, dtype: float64

# %%
walm = pd.read_csv('WMT.csv', index_col = 'Date', parse_dates = [0])
walm.shift(-1).head()
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2016-09-06  73.000000  73.050003  72.010002  72.059998  64.911324   9618300.0
# 2016-09-07  71.889999  72.320000  71.709999  71.830002  64.704163   9661200.0
# 2016-09-08  71.320000  71.510002  70.300003  70.300003  63.325943  12172600.0
# 2016-09-09  70.790001  72.239998  70.720001  71.940002  64.803238  10864000.0
# 2016-09-12  71.839996  71.910004  71.150002  71.459999  64.370857   7507900.0

# %%
walm['Adj Close'].pct_change(1)
# Out:
# Date
# 2016-09-06         NaN
# 2016-09-07   -0.012877
# 2016-09-08   -0.003191
# 2016-09-09   -0.021300
# 2016-09-12    0.023328
#                 ...
# 2021-08-27   -0.005633
# 2021-08-30    0.008053
# 2021-08-31    0.002708
# 2021-09-01   -0.002161
# 2021-09-02    0.005278
# Name: Adj Close, Length: 1258, dtype: float64

# %%
example = pd.Series([1,2,3,4,5])
example
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
example.cumprod()
# Out:
# 0      1
# 1      2
# 2      6
# 3     24
# 4    120
# dtype: int64

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Define the ticker symbol and date range
ticker = 'AAPL'
start_date = '2020-01-01'
end_date = '2021-01-01'

# Fetch the data
aapl_df = yf.download(ticker, start=start_date, end=end_date)

# Display the DataFrame
aapl_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02   72.796028   75.087502   75.150002   73.797501   74.059998
# 2020-01-03   72.088295   74.357498   75.144997   74.125000   74.287498
# 2020-01-06   72.662704   74.949997   74.989998   73.187500   73.447502
# 2020-01-07   72.320969   74.597504   75.224998   74.370003   74.959999
# 2020-01-08   73.484344   75.797501   76.110001   74.290001   74.290001
# ...                ...         ...         ...         ...         ...
# 2020-12-24  129.047546  131.970001  133.460007  131.100006  131.320007
# 2020-12-28  133.663025  136.690002  137.339996  133.509995  133.990005
# 2020-12-29  131.883316  134.869995  138.789993  134.339996  138.050003
# 2020-12-30  130.758743  133.720001  135.990005  133.399994  135.580002
# ...

# %%
inflation_df = web.DataReader('T10YIE','fred',start = '2004-01-01',end ='2020-01-01')

# %%
inflation_df
# Out:
#             T10YIE
# DATE
# 2004-01-01     NaN
# 2004-01-02    2.32
# 2004-01-05    2.35
# 2004-01-06    2.32
# 2004-01-07    2.33
# ...            ...
# 2019-12-26    1.74
# 2019-12-27    1.73
# 2019-12-30    1.75
# 2019-12-31    1.77
# 2020-01-01     NaN
#
# [4175 rows x 1 columns]

# %%
apple_ticker = yf.Ticker('AAPL')
apple_ticker.get_balance_sheet()
# Out:
#                                                 2024-09-30      2023-09-30  \
# TreasurySharesNumber                                   NaN             0.0
# OrdinarySharesNumber                         15116786000.0   15550061000.0
# ShareIssued                                  15116786000.0   15550061000.0
# NetDebt                                      76686000000.0   81123000000.0
# TotalDebt                                   106629000000.0  111088000000.0
# ...                                                    ...             ...
# CashCashEquivalentsAndShortTermInvestments   65171000000.0   61555000000.0
# OtherShortTermInvestments                    35228000000.0   31590000000.0
# CashAndCashEquivalents                       29943000000.0   29965000000.0
# CashEquivalents                               2744000000.0    1606000000.0
# CashFinancial                                27199000000.0   28359000000.0
#
# ...

# %%
spy = yf.download('SPY')
spy
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker             SPY         SPY         SPY         SPY         SPY
# Date
# 1993-01-29   24.608612   43.937500   43.968750   43.750000   43.968750
# 1993-02-01   24.783649   44.250000   44.250000   43.968750   43.968750
# 1993-02-02   24.836157   44.343750   44.375000   44.125000   44.218750
# 1993-02-03   25.098698   44.812500   44.843750   44.375000   44.406250
# 1993-02-04   25.203712   45.000000   45.093750   44.468750   44.968750
# ...                ...         ...         ...         ...         ...
# 2024-11-29  602.549988  602.549988  603.349976  599.380005  599.659973
# 2024-12-02  603.630005  603.630005  604.320007  602.469971  602.969971
# 2024-12-03  603.909973  603.909973  604.159973  602.340027  603.390015
# 2024-12-04  607.659973  607.659973  607.909973  604.950012  605.630005
# ...

# %%
spy = spy.loc['2000-01-01':'2021-01-01']

# %%
spy.head(10)

# %%
spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2000-01-03 to 2000-01-14
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Adj Close, SPY)  10 non-null     float64
#  1   (Close, SPY)      10 non-null     float64
#  2   (High, SPY)       10 non-null     float64
#  3   (Low, SPY)        10 non-null     float64
#  4   (Open, SPY)       10 non-null     float64
#  5   (Volume, SPY)     10 non-null     int64
# dtypes: float64(5), int64(1)
# memory usage: 560.0 bytes

# %%
spy = yf.download('SPY')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker             SPY         SPY         SPY         SPY         SPY
# Date
# 1993-01-29   24.608622   43.937500   43.968750   43.750000   43.968750
# 1993-02-01   24.783655   44.250000   44.250000   43.968750   43.968750
# 1993-02-02   24.836178   44.343750   44.375000   44.125000   44.218750
# 1993-02-03   25.098698   44.812500   44.843750   44.375000   44.406250
# 1993-02-04   25.203716   45.000000   45.093750   44.468750   44.968750
# ...                ...         ...         ...         ...         ...
# 2024-11-29  602.549988  602.549988  603.349976  599.380005  599.659973
# 2024-12-02  603.630005  603.630005  604.320007  602.469971  602.969971
# 2024-12-03  603.909973  603.909973  604.159973  602.340027  603.390015
# 2024-12-04  607.659973  607.659973  607.909973  604.950012  605.630005
# 2024-12-05  606.659973  606.659973  608.479980  606.306824  607.659973
#
# Price         Volume
# ...

# %%
from matplotlib import dates
import matplotlib.pyplot as plt
plt.figure(dpi = 300, figsize = (10,3))
ax = spy['Adj Close'].plot()
ax.xaxis.set_major_locator(dates.YearLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y'))

plt.savefig('adjclose', bbox_inches = 'tight')

# %%
spy['Volume'].plot(kind = 'hist', bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
plt.figure(figsize = (5,15), dpi = 300);
ax = spy['Adj Close']['2020-01-01':'2021-01-01'].plot(title = 'Covid Year');
plt.xlabel('Year - Month')
plt.ylabel('Price')

ax.xaxis.set_major_locator(dates.MonthLocator())

# %%
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
plt.figure(figsize=(10,3), dpi = 300)
ax = spy['Adj Close'].rolling(window = 200).mean().plot(label = 'Moving Average')
spy['Adj Close'].plot(ax=ax, label = 'Adjusted Close')
plt.legend()
